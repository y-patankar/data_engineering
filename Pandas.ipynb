# %% [markdown]
# <a href="https://colab.research.google.com/github/y-patankar/data_engineering/blob/practice/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas
#
# 1.   Open-source data manipulation analysis library
# 2.   It boosts the data analysis capabilities of Python
# 3.   Can load, prepare, minipulate, model and analyze data.
# 4.  It can read multiple data types
# 5.   It can sort, filer and do mathematical calculation on data.
# 6. Smooth handleing of complex analysis

# %%
import pandas as pd
df= pd.read_csv('/content/sample_data/california_housing_test.csv')
print(df)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df2= pd.read_json('/content/sample_data/anscombe.json')
print(df2)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %%
df= pd.read_csv('/content/sample_data/california_housing_test.csv')
new_df=df.dropna()
print(new_df.to_string())
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  population  households  median_income  median_house_value
# 0       -122.05     37.37                27.0       3885.0           661.0      1537.0       606.0         6.6085            344700.0
# 1       -118.30     34.26                43.0       1510.0           310.0       809.0       277.0         3.5990            176500.0
# 2       -117.81     33.78                27.0       3589.0           507.0      1484.0       495.0         5.7934            270500.0
# 3       -118.36     33.82                28.0         67.0            15.0        49.0        11.0         6.1359            330000.0
# 4       -119.67     36.33                19.0       1241.0           244.0       850.0       237.0         2.9375             81700.0
# 5       -119.56     36.51                37.0       1018.0           213.0       663.0       204.0         1.6635             67000.0
# ...

# %%
df= pd.read_csv('/content/creditcard.csv')
# print(df)
new_df=df.dropna()
print(new_df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.fillna(100,inplace=True)

# %%
df['V5'].fillna(100, inplace=True)

# %%
print(df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df_new=df.drop_duplicates()
print(df_new)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
avg_amt=new_df.groupby('Amount')['Time'].mean()
print(avg_amt)
# Out:
# Amount
# 0.00         89370.688767
# 0.01         82146.279944
# 0.02         87315.576471
# 0.03         99923.333333
# 0.04         91373.000000
#                 ...
# 11898.09     46253.000000
# 12910.93     42951.000000
# 18910.00     95286.000000
# 19656.53     48401.000000
# 25691.16    166198.000000
# Name: Time, Length: 32767, dtype: float64

# %%
#sum and min column
new_df.aggregate(['sum','min'])
# Out:
#              Time            V1            V2            V3            V4  \
# sum  2.700365e+10  3.327614e-10  9.731593e-11 -3.929017e-10  5.907168e-10
# min  0.000000e+00 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
#
#                V5            V6            V7            V8            V9  \
# sum  2.735305e-10  4.235972e-10 -1.582521e-10  3.456080e-11 -6.853398e-10
# min -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
#
#      ...           V21           V22           V23           V24  \
# sum  ...  4.710898e-11 -1.016360e-10  7.344170e-11  1.274017e-09
# min  ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
#
#               V25           V26           V27           V28       Amount  \
# sum  1.521130e-10  4.794547e-10 -1.042419e-10 -3.495693e-11  25162590.01
# min -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01         0.00
#
#      Class
# sum    492
# min      0
#
# [2 rows x 31 columns]

# %% [markdown]
# Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Date':['2023-08-01','2023-08-02','2023-08-03'],
        'Price':[100,105,110]}

df = pd.DataFrame(data)
df['Date']=pd.to_datetime(df['Date'])
df.plot(x='Date',y='Price', kind='line')
plt.xlabel('Date')
plt.ylabel('Prce')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Date':['2023-08-01','2023-08-02','2023-08-03'],
        'Price':[100,15,110]}

df = pd.DataFrame(data)
df['Date']=pd.to_datetime(df['Date'])
df.plot(x='Date',y='Price', kind='bar')
plt.xlabel('Date')
plt.ylabel('Prce')

plt.show()
